# %%
import pandas as pd

# %%
book = pd.read_parquet('../book.parquet')

# %%
book.head()
# Out:
#           exchange   symbol            timestamp      local_timestamp  \
# 0  binance-futures  BTCUSDT  1679443200138000000  1679443200485131264
# 1  binance-futures  BTCUSDT  1679443202062000000  1679443202065465600
# 2  binance-futures  BTCUSDT  1679443202688000000  1679443202691394048
# 3  binance-futures  BTCUSDT  1679443202809000000  1679443202812150528
# 4  binance-futures  BTCUSDT  1679443203186000000  1679443203188767744
#
#    asks[0].price  asks[0].amount  bids[0].price  bids[0].amount  \
# 0        28091.2          16.183        28091.1           0.001
# 1        28090.9           6.995        28090.8           0.002
# 2        28090.9           7.005        28090.8           0.002
# 3        28090.9           6.885        28090.8           0.002
# 4        28090.9           6.885        28090.8           0.002
#
#    asks[1].price  asks[1].amount  ...  bids[22].price  bids[22].amount  \
# 0        28091.3           7.874  ...         28087.8            0.006
# ...
